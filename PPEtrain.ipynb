# %% [markdown]
# <a href="https://colab.research.google.com/github/ansho1/PPEdetection/blob/main/PPEtrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First lets setup the enviornment

# %%
# !pip install --upgrade pip
# !pip install --upgrade protobuf
# !pip install numpy
# Out:
# ...
#      |████████████████████████████████| 1.5MB 20.2MB/s
# ...
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# ...
#      |████████████████████████████████| 1.0 MB 15.1 MB/s
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.12.4
#     Uninstalling protobuf-3.12.4:
#       Successfully uninstalled protobuf-3.12.4
# ...

# %%
"""!apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
#%cd /content/drive/My Drive/research/
#!protoc object_detection/protos/*.proto --python_out=.

# !python setup.py install"""

# %%
# %tensorflow_version 1.14
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.2
# ...

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# Link the notebook to the tfod setup folder to perform training, either you can upload the model or mount your drive, I will mount the drive in which I have config files and SSD model graph along with train.py required for training.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/research/
# Out:
# /content/drive/My Drive

# %%
pwd
# Out:
# '/content/drive/My Drive/research'

# %% [markdown]
# Train your model upto required epoch to minimize the loss.

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/ssdlite_mobilenet_v2_coco.config
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global step 47526: loss = 1.7390 (1.272 sec/step)
# I0225 08:02:07.100859 140706221987712 learning.py:507] global step 47526: loss = 1.7390 (1.272 sec/step)
# INFO:tensorflow:global step 47527: loss = 2.0590 (0.703 sec/step)
# I0225 08:02:07.805791 140706221987712 learning.py:507] global step 47527: loss = 2.0590 (0.703 sec/step)
# INFO:tensorflow:global step 47528: loss = 1.8521 (1.252 sec/step)
# I0225 08:02:09.059325 140706221987712 learning.py:507] global step 47528: loss = 1.8521 (1.252 sec/step)
# INFO:tensorflow:global step 47529: loss = 1.6476 (0.765 sec/step)
# I0225 08:02:09.860167 140706221987712 learning.py:507] global step 47529: loss = 1.6476 (0.765 sec/step)
# INFO:tensorflow:global step 47530: loss = 1.9766 (1.046 sec/step)
# I0225 08:02:10.921169 140706221987712 learning.py:507] global step 47530: loss = 1.9766 (1.046 sec/step)
# INFO:tensorflow:global step 47531: loss = 1.6455 (0.833 sec/step)
# ...

# %% [markdown]
# After the training has been completed, export the model.ckpt file and convert it to inderence graph to use it for testing

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/ssdlite_mobilenet_v2_coco.config --trained_checkpoint_prefix training/model.ckpt-50000 --output_directory inference_graph
# Out:
# python3: can't open file 'export_inference_graph.py': [Errno 2] No such file or directory
